# %%
import pandas as pd

import scipy.stats as stats
import statistics

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.read_csv('auto.csv')
data.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                164  alfa-romero       gas        std
# 1          3                164  alfa-romero       gas        std
# 2          1                164  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Рассчитать основные статистики для переменных(среднее,
# медиана, мода, мин/макс, сред. отклонение)

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         126.365854   98.756585  174.049268   65.907805
# std      1.245307          35.438400    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.324878    3.253366
# std      2.443522   520.680204    41.642693    0.273049    0.313937
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null int64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null float64
# stroke               205 non-null float64
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.select_dtypes(include='object').mode()
# Out:
#      make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 0  toyota       gas        std         four      sedan          fwd
#
#   engine-location engine-type num-of-cylinders fuel-system
# 0           front         ohc             four        mpfi

# %%
data.median()
# Out:
# symboling                1.00
# normalized-losses      122.00
# wheel-base              97.00
# length                 173.20
# width                   65.50
# height                  54.10
# curb-weight           2414.00
# engine-size            120.00
# bore                     3.31
# stroke                   3.29
# compression-ratio        9.00
# horsepower              95.00
# peak-rpm              5200.00
# city-mpg                24.00
# highway-mpg             30.00
# price                10295.00
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %%
# import pandas_profiling  установить и протестировать модуль разведочного анализа

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['price'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('price')
plt.title('Частотный график avg_vote (разбиение интервала по 10 элементов)')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Формируем семплы, проверяем их кол-во, далее делаем. Одинаковая дисперсия. Запись в районе 8 минуты

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# статистик - разница между средними. п-валуе посмотреть
# P-value) — величина, используемая при тестировании статистических гипотез. Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода).

# %% [markdown]
# т-тест разница между средними, п-валуе показывает уверенность в том что результат не случаен
# гипотеза верная если по умолчанию **0,05** или 0,1 или 0,15.
# Запись примерно на 13 минуте

# %%
data['price'].skew()
# Out:
# 1.7663998888191028

# %%
data['price'].kurtosis()
# Out:
# 2.948637293212561

# %%
sns_plot = sns.pairplot(
    data[['price', 'horsepower', 'city-mpg']])
sns_plot

# %%
data_price = data['price']
data_horsepower = data['horsepower']
data_citympg = data['city-mpg']

# %%
stats.ttest_ind(data_price.sample(n=205), data_horsepower.sample(n=205))
# Out:
# Ttest_indResult(statistic=23.337064505286627, pvalue=3.909801820534587e-77)

# %%
stats.ttest_ind(data_price.sample(n=205), data_citympg.sample(n=205))
# Out:
# Ttest_indResult(statistic=23.480225513373956, pvalue=9.329776663935988e-78)
